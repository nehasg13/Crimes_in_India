# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df1= pd.read_csv("C:/Users/mneha/Downloads/India_Crime - Copy (1)/India_Crime - Copy/01_District_wise_crimes_committed_IPC_2001_2012.csv")
df1
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
df1.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# ...

# %%
df1.dtypes
# Out:
# STATE/UT                                               object
# DISTRICT                                               object
# YEAR                                                    int64
# MURDER                                                  int64
# ATTEMPT TO MURDER                                       int64
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               int64
# RAPE                                                    int64
# CUSTODIAL RAPE                                          int64
# OTHER RAPE                                              int64
# KIDNAPPING & ABDUCTION                                  int64
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             int64
# KIDNAPPING AND ABDUCTION OF OTHERS                      int64
# DACOITY                                                 int64
# PREPARATION AND ASSEMBLY FOR DACOITY                    int64
# ROBBERY                                                 int64
# ...

# %%
tt = df1.groupby("STATE/UT")["TOTAL IPC CRIMES"].sum().sort_values(ascending = False)

print("Crime by Each state")
tt
# Out:
# Crime by Each state
# STATE/UT
# MADHYA PRADESH       4827540
# MAHARASHTRA          4546872
# TAMIL NADU           4120352
# ANDHRA PRADESH       4037962
# UTTAR PRADESH        3716148
# RAJASTHAN            3711832
# KARNATAKA            2962126
# KERALA               2874918
# GUJARAT              2771550
# BIHAR                2692586
# WEST BENGAL          2238608
# ODISHA               1295892
# DELHI UT             1266348
# ASSAM                1195528
# HARYANA              1190606
# CHHATTISGARH         1122054
# JHARKHAND             844702
# PUNJAB                768262
# JAMMU & KASHMIR       518310
# HIMACHAL PRADESH      309896
# UTTARAKHAND           206408
# PUDUCHERRY            108232
# TRIPURA               105468
# CHANDIGARH             81614
# MANIPUR                70144
# GOA                    64102
# ARUNACHAL PRADESH      55304
# MIZORAM                52292
# MEGHALAYA              50498
# NAGALAND               26266
# A & N ISLANDS          18204
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = tt.index[:12], y = tt[:12]).set(title = "Crime by Each state")
# Out:
# [Text(0.5, 1.0, 'Crime by Each state')]

# %%
df3= pd.DataFrame(tt)

# %%
df3
# Out:
#                    TOTAL IPC CRIMES
# STATE/UT
# MADHYA PRADESH              4827540
# MAHARASHTRA                 4546872
# TAMIL NADU                  4120352
# ANDHRA PRADESH              4037962
# UTTAR PRADESH               3716148
# RAJASTHAN                   3711832
# KARNATAKA                   2962126
# KERALA                      2874918
# GUJARAT                     2771550
# BIHAR                       2692586
# WEST BENGAL                 2238608
# ODISHA                      1295892
# DELHI UT                    1266348
# ASSAM                       1195528
# HARYANA                     1190606
# CHHATTISGARH                1122054
# JHARKHAND                    844702
# PUNJAB                       768262
# JAMMU & KASHMIR              518310
# HIMACHAL PRADESH             309896
# UTTARAKHAND                  206408
# PUDUCHERRY                   108232
# TRIPURA                      105468
# CHANDIGARH                    81614
# MANIPUR                       70144
# ...

# %%
tt1 = df1.groupby("YEAR")[ "TOTAL IPC CRIMES"].sum()

print("Crimes every year")
tt1
# Out:
# Crimes every year
# YEAR
# 2001    3538616
# 2002    3560660
# 2003    3432240
# 2004    3664020
# 2005    3645204
# 2006    3756586
# 2007    3979346
# 2008    4186758
# 2009    4242690
# 2010    4449662
# 2011    4651150
# 2012    4774376
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = tt1.index[:12], y = tt1[:12]).set(title = "Year-on-year total crime rate")
# Out:
# [Text(0.5, 1.0, 'Year-on-year total crime rate')]

# %%
df2= pd.read_csv("C:/Users/mneha/OneDrive/Documents/GitHub/DSData/capstone_phase1.csv")
df2
# Out:
#                  States or Uts Population (2001) Population (2011)  \
# 0                Uttar Pradesh      16,60,53,600      19,95,81,477
# 1                  Maharashtra       9,67,52,500      11,23,72,972
# 2                        Bihar       8,28,79,910      10,38,04,630
# 3                  West Bengal       8,02,21,300       9,13,47,736
# 4               Madhya Pradesh       6,03,85,090       7,25,97,565
# 5                   Tamil Nadu       6,21,11,390       7,21,38,958
# 6                    Rajasthan       5,64,73,300       6,86,21,012
# 7                    Karnataka       5,27,34,986       6,11,30,704
# 8                      Gujarat       5,05,97,200       6,03,83,628
# 9               Andhra Pradesh       7,57,28,400       4,93,86,799
# 10                      Odisha       3,67,07,900       4,19,47,358
# 11                      Kerela       3,18,39,000       3,33,87,677
# 12                   Jharkhand       2,69,46,070       3,29,88,134
# ...

# %%
df2.dropna()
# Out:
#                  States or Uts Population (2001) Population (2011)  \
# 0                Uttar Pradesh      16,60,53,600      19,95,81,477
# 1                  Maharashtra       9,67,52,500      11,23,72,972
# 2                        Bihar       8,28,79,910      10,38,04,630
# 3                  West Bengal       8,02,21,300       9,13,47,736
# 4               Madhya Pradesh       6,03,85,090       7,25,97,565
# 5                   Tamil Nadu       6,21,11,390       7,21,38,958
# 6                    Rajasthan       5,64,73,300       6,86,21,012
# 7                    Karnataka       5,27,34,986       6,11,30,704
# 8                      Gujarat       5,05,97,200       6,03,83,628
# 9               Andhra Pradesh       7,57,28,400       4,93,86,799
# 10                      Odisha       3,67,07,900       4,19,47,358
# 11                      Kerela       3,18,39,000       3,33,87,677
# 12                   Jharkhand       2,69,46,070       3,29,88,134
# ...

# %%
##This data is collected from wikipedia.

# %%
tt = df1.groupby("STATE/UT")["TOTAL IPC CRIMES"].sum()

print("Crime by Each state")
tt
# Out:
# Crime by Each state
# STATE/UT
# A & N ISLANDS          18204
# ANDHRA PRADESH       4037962
# ARUNACHAL PRADESH      55304
# ASSAM                1195528
# BIHAR                2692586
# CHANDIGARH             81614
# CHHATTISGARH         1122054
# D & N HAVELI            9302
# DAMAN & DIU             5896
# DELHI UT             1266348
# GOA                    64102
# GUJARAT              2771550
# HARYANA              1190606
# HIMACHAL PRADESH      309896
# JAMMU & KASHMIR       518310
# JHARKHAND             844702
# KARNATAKA            2962126
# KERALA               2874918
# LAKSHADWEEP             1486
# MADHYA PRADESH       4827540
# MAHARASHTRA          4546872
# MANIPUR                70144
# MEGHALAYA              50498
# MIZORAM                52292
# NAGALAND               26266
# ODISHA               1295892
# PUDUCHERRY            108232
# PUNJAB                768262
# RAJASTHAN            3711832
# SIKKIM                 14000
# TAMIL NADU           4120352
# ...

# %%
data = {'Literacy Rate': ["86.63%",
"67.02%",
"65.38%",
"72.19%",
"61.80%",
"86.05%",
"70.28%",
"76.24%",
"87.10%",
"86.21%",
"88.70%",
"78.03%",
"75.55%",
"82.80%",
"67.16%",
"66.41%",
"75.36%",
"94.00%",
"91.85%",
"69.32%",
"82.34%",
"76.94%",
"74.43%",
"91.33%",
"79.55%",
"72.87%",
"85.85%",
"75.84%",
"66.11%",
"81.42%",
"80.33%",
"87.22%",
"67.68%",
"78.82%",
"76.26%"
]}

# %%
df4= pd.DataFrame(tt)
df4
# Out:
#                    TOTAL IPC CRIMES
# STATE/UT
# A & N ISLANDS                 18204
# ANDHRA PRADESH              4037962
# ARUNACHAL PRADESH             55304
# ASSAM                       1195528
# BIHAR                       2692586
# CHANDIGARH                    81614
# CHHATTISGARH                1122054
# D & N HAVELI                   9302
# DAMAN & DIU                    5896
# DELHI UT                    1266348
# GOA                           64102
# GUJARAT                     2771550
# HARYANA                     1190606
# HIMACHAL PRADESH             309896
# JAMMU & KASHMIR              518310
# JHARKHAND                    844702
# KARNATAKA                   2962126
# KERALA                      2874918
# LAKSHADWEEP                    1486
# MADHYA PRADESH              4827540
# MAHARASHTRA                 4546872
# MANIPUR                       70144
# MEGHALAYA                     50498
# MIZORAM                       52292
# NAGALAND                      26266
# ...

# %%
df4.insert(1, "Literacy Rate", ["86.63%",
"67.02%",
"65.38%",
"72.19%",
"61.80%",
"86.05%",
"70.28%",
"76.24%",
"87.10%",
"86.21%",
"88.70%",
"78.03%",
"75.55%",
"82.80%",
"67.16%",
"66.41%",
"75.36%",
"94.00%",
"91.85%",
"69.32%",
"82.34%",
"76.94%",
"74.43%",
"91.33%",
"79.55%",
"72.87%",
"85.85%",
"75.84%",
"66.11%",
"81.42%",
"80.33%",
"87.22%",
"67.68%",
"78.82%",
"76.26%"])

# %%
df4
# Out:
#                    TOTAL IPC CRIMES Literacy Rate
# STATE/UT
# A & N ISLANDS                 18204        86.63%
# ANDHRA PRADESH              4037962        67.02%
# ARUNACHAL PRADESH             55304        65.38%
# ASSAM                       1195528        72.19%
# BIHAR                       2692586        61.80%
# CHANDIGARH                    81614        86.05%
# CHHATTISGARH                1122054        70.28%
# D & N HAVELI                   9302        76.24%
# DAMAN & DIU                    5896        87.10%
# DELHI UT                    1266348        86.21%
# GOA                           64102        88.70%
# GUJARAT                     2771550        78.03%
# HARYANA                     1190606        75.55%
# HIMACHAL PRADESH             309896        82.80%
# JAMMU & KASHMIR              518310        67.16%
# JHARKHAND                    844702        66.41%
# KARNATAKA                   2962126        75.36%
# KERALA                      2874918        94.00%
# ...

# %%
sns.barplot(x=df4['TOTAL IPC CRIMES'], y= df4['Literacy Rate'])
# Out:
# <AxesSubplot:xlabel='TOTAL IPC CRIMES', ylabel='Literacy Rate'>

# %%
##We cannot find a relevant relation between literacy rate and Total crimes. And we have chosen the literacy rate of 2011.

# %%
Murder = df1.groupby("STATE/UT")["MURDER"].sum().sort_values(ascending=False)

print("Murder by Each state")
Murder
# Out:
# Murder by Each state
# STATE/UT
# UTTAR PRADESH        130886
# BIHAR                 82490
# MAHARASHTRA           65534
# ANDHRA PRADESH        63512
# MADHYA PRADESH        56798
# WEST BENGAL           42112
# TAMIL NADU            40254
# KARNATAKA             39874
# JHARKHAND             38120
# RAJASTHAN             31688
# ASSAM                 30864
# ODISHA                28906
# GUJARAT               27550
# CHHATTISGARH          24120
# HARYANA               20942
# PUNJAB                18986
# JAMMU & KASHMIR       12608
# DELHI UT              12410
# KERALA                 9466
# UTTARAKHAND            5896
# TRIPURA                4044
# MANIPUR                3910
# MEGHALAYA              3460
# HIMACHAL PRADESH       2908
# NAGALAND               2076
# ARUNACHAL PRADESH      1682
# GOA                     974
# MIZORAM                 806
# PUDUCHERRY              714
# CHANDIGARH              486
# SIKKIM                  332
# A & N ISLANDS           320
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Murder.index[:10], y = Murder[:10]).set(title = "No.of Murders by Each state")
# Out:
# [Text(0.5, 1.0, 'No.of Murders by Each state')]

# %%
ATM = df1.groupby("STATE/UT")["ATTEMPT TO MURDER"].sum().sort_values(ascending=False)

print("Murder by Each state")
ATM
# Out:
# Murder by Each state
# STATE/UT
# UTTAR PRADESH        121040
# BIHAR                 81838
# MADHYA PRADESH        58916
# TAMIL NADU            53194
# ANDHRA PRADESH        44840
# RAJASTHAN             42684
# MAHARASHTRA           41178
# KARNATAKA             37024
# ODISHA                31304
# WEST BENGAL           29386
# JHARKHAND             24540
# PUNJAB                20794
# JAMMU & KASHMIR       20606
# CHHATTISGARH          15820
# HARYANA               14868
# GUJARAT               12224
# ASSAM                 11324
# KERALA                10654
# DELHI UT              10554
# MANIPUR                7072
# UTTARAKHAND            5254
# HIMACHAL PRADESH       1670
# TRIPURA                1362
# MEGHALAYA              1202
# NAGALAND                928
# ARUNACHAL PRADESH       834
# PUDUCHERRY              686
# CHANDIGARH              602
# GOA                     538
# MIZORAM                 516
# SIKKIM                  222
# A & N ISLANDS           130
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = ATM.index[:10], y = ATM[:10]).set(title = "No.of Attempt to Murders by Each state")
# Out:
# [Text(0.5, 1.0, 'No.of Attempt to Murders by Each state')]

# %%
CH = df1.groupby("STATE/UT")["CULPABLE HOMICIDE NOT AMOUNTING TO MURDER"].sum().sort_values(ascending=False)

print("Culpable Homicide")
CH
# Out:
# Culpable Homicide
# STATE/UT
# UTTAR PRADESH        34532
# WEST BENGAL          12666
# BIHAR                 7344
# KERALA                3794
# MADHYA PRADESH        3668
# ANDHRA PRADESH        3526
# PUNJAB                3116
# MAHARASHTRA           2818
# JHARKHAND             2462
# RAJASTHAN             1778
# DELHI UT              1766
# KARNATAKA             1714
# HARYANA               1714
# ASSAM                 1436
# ODISHA                1396
# UTTARAKHAND           1028
# GUJARAT                860
# CHHATTISGARH           696
# JAMMU & KASHMIR        694
# TAMIL NADU             686
# HIMACHAL PRADESH       260
# NAGALAND               202
# MEGHALAYA              168
# CHANDIGARH             158
# PUDUCHERRY             156
# MIZORAM                134
# GOA                    134
# MANIPUR                 84
# SIKKIM                  76
# ARUNACHAL PRADESH       72
# A & N ISLANDS           42
# TRIPURA                 38
# D & N HAVELI             6
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = CH.index[:10], y = CH[:10]).set(title = "culpable homicide not ammountting to Murders of Each state")
# Out:
# [Text(0.5, 1.0, 'culpable homicide not ammountting to Murders of Each state')]

# %%
RAPE = df1.groupby("STATE/UT")["RAPE"].sum().sort_values(ascending=False)

print("Rape")
RAPE
# Out:
# Rape
# STATE/UT
# MADHYA PRADESH       72174
# WEST BENGAL          41574
# UTTAR PRADESH        38116
# MAHARASHTRA          35972
# ASSAM                32356
# RAJASTHAN            31596
# ANDHRA PRADESH       26958
# BIHAR                26248
# CHHATTISGARH         23676
# ODISHA               22860
# JHARKHAND            18318
# KERALA               14894
# TAMIL NADU           13904
# DELHI UT             12848
# HARYANA              12820
# PUNJAB               10918
# KARNATAKA            10348
# GUJARAT               8498
# JAMMU & KASHMIR       5620
# TRIPURA               4116
# HIMACHAL PRADESH      3608
# UTTARAKHAND           2756
# MEGHALAYA             2040
# MIZORAM               1652
# ARUNACHAL PRADESH     1000
# MANIPUR                774
# GOA                    700
# CHANDIGARH             562
# NAGALAND               440
# SIKKIM                 390
# A & N ISLANDS          218
# PUDUCHERRY             154
# D & N HAVELI           112
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = RAPE.index[:10], y = RAPE[:10]).set(title = "No. of Rape by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Rape by Each state')]

# %%
CR = df1.groupby("STATE/UT")["CUSTODIAL RAPE"].sum().sort_values(ascending=False)

print(" Custodial Rape")
CR
# Out:
#  Custodial Rape
# STATE/UT
# ASSAM                10
# JHARKHAND            10
# MAHARASHTRA           4
# BIHAR                 4
# UTTAR PRADESH         4
# TAMIL NADU            4
# ANDHRA PRADESH        4
# KARNATAKA             4
# HARYANA               2
# MADHYA PRADESH        2
# MIZORAM               2
# PUNJAB                2
# PUDUCHERRY            0
# ODISHA                0
# NAGALAND              0
# MEGHALAYA             0
# RAJASTHAN             0
# SIKKIM                0
# TRIPURA               0
# UTTARAKHAND           0
# A & N ISLANDS         0
# KERALA                0
# MANIPUR               0
# LAKSHADWEEP           0
# JAMMU & KASHMIR       0
# HIMACHAL PRADESH      0
# GUJARAT               0
# GOA                   0
# DELHI UT              0
# DAMAN & DIU           0
# D & N HAVELI          0
# CHHATTISGARH          0
# CHANDIGARH            0
# ARUNACHAL PRADESH     0
# WEST BENGAL           0
# Name: CUSTODIAL RAPE, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = CR.index[:10], y = CR[:10]).set(title = "No. of  Custodial Rape by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of  Custodial Rape by Each state')]

# %%
OR = df1.groupby("STATE/UT")["OTHER RAPE"].sum().sort_values(ascending=False)

print("Other Rape")
OR
# Out:
# Other Rape
# STATE/UT
# MADHYA PRADESH       72172
# WEST BENGAL          41574
# UTTAR PRADESH        38112
# MAHARASHTRA          35968
# ASSAM                32346
# RAJASTHAN            31596
# ANDHRA PRADESH       26954
# BIHAR                26244
# CHHATTISGARH         23676
# ODISHA               22860
# JHARKHAND            18308
# KERALA               14894
# TAMIL NADU           13900
# DELHI UT             12848
# HARYANA              12818
# PUNJAB               10916
# KARNATAKA            10344
# GUJARAT               8498
# JAMMU & KASHMIR       5620
# TRIPURA               4116
# HIMACHAL PRADESH      3608
# UTTARAKHAND           2756
# MEGHALAYA             2040
# MIZORAM               1650
# ARUNACHAL PRADESH     1000
# MANIPUR                774
# GOA                    700
# CHANDIGARH             562
# NAGALAND               440
# SIKKIM                 390
# A & N ISLANDS          218
# PUDUCHERRY             154
# D & N HAVELI           112
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = OR.index[:10], y = OR[:10]).set(title = "No. of Other Rape by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Other Rape by Each state')]

# %%
KA = df1.groupby("STATE/UT")["KIDNAPPING & ABDUCTION"].sum().sort_values(ascending=False)

print("Kidnapping and Abduction")
KA
# Out:
# Kidnapping and Abduction
# STATE/UT
# UTTAR PRADESH        118532
# BIHAR                 74440
# RAJASTHAN             61454
# ASSAM                 55878
# WEST BENGAL           51998
# DELHI UT              50166
# ANDHRA PRADESH        42478
# TAMIL NADU            30606
# GUJARAT               30492
# MAHARASHTRA           30202
# MADHYA PRADESH        23916
# KARNATAKA             20058
# ODISHA                19458
# JAMMU & KASHMIR       19330
# HARYANA               17312
# JHARKHAND             16952
# PUNJAB                15238
# CHHATTISGARH           6690
# KERALA                 5782
# UTTARAKHAND            5704
# MANIPUR                3622
# HIMACHAL PRADESH       3596
# TRIPURA                2886
# ARUNACHAL PRADESH      1714
# MEGHALAYA              1458
# CHANDIGARH             1280
# NAGALAND                784
# GOA                     472
# PUDUCHERRY              338
# D & N HAVELI            282
# MIZORAM                 192
# A & N ISLANDS           188
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = KA.index[:10], y = KA[:10]).set(title = "No. of Kidnapping and abduction by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Kidnapping and abduction by Each state')]

# %%
KAW = df1.groupby("STATE/UT")["KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS"].sum().sort_values(ascending=False)

print("Kidnapping and Abduction of women and girls")
KAW
# Out:
# Kidnapping and Abduction of women and girls
# STATE/UT
# UTTAR PRADESH        95180
# RAJASTHAN            49342
# ASSAM                45840
# WEST BENGAL          43546
# BIHAR                38778
# DELHI UT             31300
# ANDHRA PRADESH       29872
# GUJARAT              25836
# TAMIL NADU           24872
# MAHARASHTRA          21706
# MADHYA PRADESH       18486
# JAMMU & KASHMIR      17640
# ODISHA               16582
# HARYANA              12258
# PUNJAB               10770
# KARNATAKA            10630
# JHARKHAND            10564
# CHHATTISGARH          5260
# UTTARAKHAND           4668
# KERALA                3796
# HIMACHAL PRADESH      3082
# MANIPUR               2114
# TRIPURA               1750
# ARUNACHAL PRADESH     1116
# CHANDIGARH            1068
# MEGHALAYA              528
# GOA                    328
# PUDUCHERRY             242
# D & N HAVELI           188
# A & N ISLANDS          154
# NAGALAND               142
# SIKKIM                 124
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = KAW.index[:10], y = KAW[:10]).set(title = "No. of Kidnapping and abduction of women and girls by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Kidnapping and abduction of women and girls by Each state')]

# %%
KAO = df1.groupby("STATE/UT")["KIDNAPPING AND ABDUCTION OF OTHERS"].sum().sort_values(ascending=False)

print("Kidnapping and Abduction of women and girls")
KAO
# Out:
# Kidnapping and Abduction of women and girls
# STATE/UT
# BIHAR                35662
# UTTAR PRADESH        23352
# DELHI UT             18866
# ANDHRA PRADESH       12606
# RAJASTHAN            12112
# ASSAM                10038
# KARNATAKA             9428
# MAHARASHTRA           8496
# WEST BENGAL           8452
# JHARKHAND             6388
# TAMIL NADU            5734
# MADHYA PRADESH        5430
# HARYANA               5054
# GUJARAT               4656
# PUNJAB                4468
# ODISHA                2876
# KERALA                1986
# JAMMU & KASHMIR       1690
# MANIPUR               1508
# CHHATTISGARH          1430
# TRIPURA               1136
# UTTARAKHAND           1036
# MEGHALAYA              930
# NAGALAND               642
# ARUNACHAL PRADESH      598
# HIMACHAL PRADESH       514
# CHANDIGARH             212
# MIZORAM                172
# GOA                    144
# PUDUCHERRY              96
# D & N HAVELI            94
# A & N ISLANDS           34
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = KAO.index[:10], y = KAO[:10]).set(title = "No. of Kidnapping and abduction of others by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Kidnapping and abduction of others by Each state')]

# %%
DAC = df1.groupby("STATE/UT")["DACOITY"].sum().sort_values(ascending=False)

print("Dacoity")
DAC
# Out:
# Dacoity
# STATE/UT
# BIHAR                22198
# MAHARASHTRA          16350
# JHARKHAND            11812
# UTTAR PRADESH         9618
# ASSAM                 8340
# GUJARAT               7684
# ODISHA                6762
# WEST BENGAL           5284
# KARNATAKA             5162
# ANDHRA PRADESH        3974
# MADHYA PRADESH        3310
# CHHATTISGARH          2936
# HARYANA               2750
# KERALA                2728
# TAMIL NADU            2474
# MEGHALAYA             1596
# RAJASTHAN             1126
# PUNJAB                 920
# DELHI UT               762
# UTTARAKHAND            714
# ARUNACHAL PRADESH      520
# TRIPURA                452
# JAMMU & KASHMIR        376
# NAGALAND               250
# GOA                    110
# MANIPUR                 96
# HIMACHAL PRADESH        90
# MIZORAM                 90
# D & N HAVELI            80
# PUDUCHERRY              76
# DAMAN & DIU             68
# CHANDIGARH              62
# A & N ISLANDS           30
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = DAC.index[:10], y = DAC[:10]).set(title = "No. of Dacoity by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Dacoity by Each state')]

# %%
prep = df1.groupby("STATE/UT")["PREPARATION AND ASSEMBLY FOR DACOITY"].sum().sort_values(ascending=False)

print("Preparation and assembly for dacoity")
prep
# Out:
# Preparation and assembly for dacoity
# STATE/UT
# WEST BENGAL          21614
# MAHARASHTRA           7314
# KARNATAKA             5426
# HARYANA               4840
# KERALA                3558
# MADHYA PRADESH        3082
# PUNJAB                2672
# BIHAR                 2530
# DELHI UT              2482
# MANIPUR               2242
# UTTAR PRADESH         1876
# RAJASTHAN             1562
# ODISHA                1360
# JHARKHAND             1048
# TAMIL NADU             614
# ASSAM                  506
# GUJARAT                366
# CHHATTISGARH           336
# ANDHRA PRADESH         160
# PUDUCHERRY              90
# UTTARAKHAND             72
# CHANDIGARH              66
# MEGHALAYA               34
# TRIPURA                 20
# ARUNACHAL PRADESH        8
# HIMACHAL PRADESH         2
# DAMAN & DIU              2
# NAGALAND                 0
# MIZORAM                  0
# LAKSHADWEEP              0
# JAMMU & KASHMIR          0
# SIKKIM                   0
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = prep.index[:10], y = prep[:10]).set(title = "No. of preparation and assembly for dacoity by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of preparation and assembly for dacoity by Each state')]

# %%
ROB = df1.groupby("STATE/UT")["ROBBERY"].sum().sort_values(ascending=False)

print("Robbery")
ROB
# Out:
# Robbery
# STATE/UT
# MAHARASHTRA          75438
# UTTAR PRADESH        61534
# BIHAR                47332
# MADHYA PRADESH       44628
# KARNATAKA            34574
# ODISHA               29410
# GUJARAT              28766
# TAMIL NADU           22544
# RAJASTHAN            18142
# JHARKHAND            17422
# KERALA               16658
# ANDHRA PRADESH       15210
# ASSAM                14934
# WEST BENGAL          14708
# DELHI UT             12922
# HARYANA              11742
# CHHATTISGARH         10226
# UTTARAKHAND           3980
# PUNJAB                3656
# JAMMU & KASHMIR       2624
# NAGALAND              2084
# MEGHALAYA             1944
# ARUNACHAL PRADESH     1686
# TRIPURA               1554
# CHANDIGARH             794
# GOA                    596
# HIMACHAL PRADESH       472
# MIZORAM                228
# PUDUCHERRY             178
# MANIPUR                166
# A & N ISLANDS          148
# SIKKIM                 128
# D & N HAVELI            60
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = ROB.index[:10], y = ROB[:10]).set(title = "No. ofRobbery by Each state")
# Out:
# [Text(0.5, 1.0, 'No. ofRobbery by Each state')]

# %%
BUR = df1.groupby("STATE/UT")["BURGLARY"].sum().sort_values(ascending=False)

print("Bruglary")
BUR
# Out:
# Bruglary
# STATE/UT
# MAHARASHTRA          371234
# MADHYA PRADESH       274692
# ANDHRA PRADESH       194672
# KARNATAKA            146596
# UTTAR PRADESH        131174
# RAJASTHAN            130536
# GUJARAT              121378
# TAMIL NADU           106678
# HARYANA               93008
# KERALA                92742
# CHHATTISGARH          89312
# BIHAR                 80586
# ODISHA                73010
# ASSAM                 69504
# PUNJAB                55242
# DELHI UT              47110
# JAMMU & KASHMIR       34100
# JHARKHAND             33360
# HIMACHAL PRADESH      19378
# UTTARAKHAND           11156
# WEST BENGAL           11000
# MIZORAM                9496
# GOA                    7400
# CHANDIGARH             5894
# ARUNACHAL PRADESH      5560
# TRIPURA                4808
# MEGHALAYA              3776
# NAGALAND               2292
# PUDUCHERRY             2128
# A & N ISLANDS          1784
# SIKKIM                 1754
# MANIPUR                1510
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = BUR.index[:10], y = BUR[:10]).set(title = "No. of burglary by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of burglary by Each state')]

# %%
THEFT = df1.groupby("STATE/UT")["THEFT"].sum().sort_values(ascending=False)

print("Theft")
THEFT
# Out:
# Theft
# STATE/UT
# MAHARASHTRA          1113614
# UTTAR PRADESH         624094
# ANDHRA PRADESH        574380
# MADHYA PRADESH        527720
# RAJASTHAN             465948
# DELHI UT              463092
# GUJARAT               426414
# KARNATAKA             399920
# WEST BENGAL           380936
# TAMIL NADU            370320
# BIHAR                 306744
# HARYANA               262788
# ASSAM                 170950
# ODISHA                165674
# JHARKHAND             142644
# CHHATTISGARH          125746
# KERALA                124706
# PUNJAB                101006
# JAMMU & KASHMIR        51534
# UTTARAKHAND            40070
# CHANDIGARH             36948
# MIZORAM                19606
# HIMACHAL PRADESH       19316
# GOA                    16090
# PUDUCHERRY             14732
# MEGHALAYA              12008
# ARUNACHAL PRADESH      10356
# MANIPUR                 9668
# TRIPURA                 9246
# NAGALAND                7604
# A & N ISLANDS           2248
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = THEFT.index[:10], y = THEFT[:10]).set(title = "No. of Theft by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Theft by Each state')]

# %%
AT = df1.groupby("STATE/UT")["AUTO THEFT"].sum().sort_values(ascending=False)

print("Auto Theft")
AT
# Out:
# Auto Theft
# STATE/UT
# MAHARASHTRA          336464
# UTTAR PRADESH        292502
# DELHI UT             254034
# RAJASTHAN            210714
# MADHYA PRADESH       200224
# GUJARAT              194018
# KARNATAKA            170888
# HARYANA              167132
# ANDHRA PRADESH       145288
# TAMIL NADU            99306
# WEST BENGAL           76128
# BIHAR                 68442
# ODISHA                45142
# KERALA                42932
# PUNJAB                42508
# CHHATTISGARH          40390
# JHARKHAND             37000
# ASSAM                 30958
# CHANDIGARH            18390
# JAMMU & KASHMIR       16074
# UTTARAKHAND           14784
# PUDUCHERRY             9028
# HIMACHAL PRADESH       5904
# GOA                    5754
# MANIPUR                5628
# MEGHALAYA              2932
# NAGALAND               2236
# ARUNACHAL PRADESH      2152
# TRIPURA                1218
# MIZORAM                 928
# DAMAN & DIU             684
# D & N HAVELI            578
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = AT.index[:10], y = AT[:10]).set(title = "No. of Auto Theft by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Auto Theft by Each state')]

# %%
OT = df1.groupby("STATE/UT")["OTHER THEFT"].sum().sort_values(ascending=False)

print("Other Theft")
OT
# Out:
# Other Theft
# STATE/UT
# MAHARASHTRA          777150
# ANDHRA PRADESH       429092
# UTTAR PRADESH        331592
# MADHYA PRADESH       327496
# WEST BENGAL          304808
# TAMIL NADU           271014
# RAJASTHAN            255234
# BIHAR                238302
# GUJARAT              232396
# KARNATAKA            229032
# DELHI UT             209058
# ASSAM                139992
# ODISHA               120532
# JHARKHAND            105644
# HARYANA               95656
# CHHATTISGARH          85356
# KERALA                81774
# PUNJAB                58498
# JAMMU & KASHMIR       35460
# UTTARAKHAND           25286
# MIZORAM               18678
# CHANDIGARH            18558
# HIMACHAL PRADESH      13412
# GOA                   10336
# MEGHALAYA              9076
# ARUNACHAL PRADESH      8204
# TRIPURA                8028
# PUDUCHERRY             5704
# NAGALAND               5368
# MANIPUR                4040
# A & N ISLANDS          2078
# SIKKIM                 1850
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = OT.index[:10], y = OT[:10]).set(title = "No. of Other Theft by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Other Theft by Each state')]

# %%
RIOTS = df1.groupby("STATE/UT")["RIOTS"].sum().sort_values(ascending=False)

print("Riots")
RIOTS
# Out:
# Riots
# STATE/UT
# BIHAR                210192
# KERALA               192548
# MAHARASHTRA          180488
# KARNATAKA            156842
# UTTAR PRADESH        108220
# WEST BENGAL          102308
# TAMIL NADU            74736
# RAJASTHAN             72146
# ASSAM                 69926
# MADHYA PRADESH        62248
# JHARKHAND             57198
# ANDHRA PRADESH        54918
# GUJARAT               44384
# ODISHA                41754
# JAMMU & KASHMIR       32414
# HARYANA               25312
# CHHATTISGARH          21794
# HIMACHAL PRADESH      14152
# UTTARAKHAND           10404
# TRIPURA                4050
# PUDUCHERRY             3570
# DELHI UT               1992
# MANIPUR                1702
# GOA                    1626
# CHANDIGARH             1510
# ARUNACHAL PRADESH       680
# DAMAN & DIU             532
# D & N HAVELI            520
# SIKKIM                  514
# LAKSHADWEEP             306
# MEGHALAYA               294
# A & N ISLANDS           280
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = RIOTS.index[:10], y = RIOTS[:10]).set(title = "No. of Riots by Each state")
# Out:
# [Text(0.5, 1.0, 'No. of Riots by Each state')]

# %%
CRB = df1.groupby("STATE/UT")["CRIMINAL BREACH OF TRUST"].sum().sort_values(ascending=False)

print("Criminal Breach of trust")
CRB
# Out:
# Criminal Breach of trust
# STATE/UT
# UTTAR PRADESH        76704
# MAHARASHTRA          41532
# GUJARAT              33178
# BIHAR                31056
# ANDHRA PRADESH       24256
# RAJASTHAN            19348
# WEST BENGAL          17838
# ASSAM                16804
# HARYANA              16708
# MADHYA PRADESH       13066
# KARNATAKA            10784
# DELHI UT              9450
# JHARKHAND             9114
# KERALA                8542
# PUNJAB                7192
# ODISHA                6956
# TAMIL NADU            6080
# UTTARAKHAND           3518
# CHHATTISGARH          3410
# JAMMU & KASHMIR       2980
# HIMACHAL PRADESH      2598
# GOA                   1122
# ARUNACHAL PRADESH     1010
# CHANDIGARH             822
# MANIPUR                780
# TRIPURA                762
# MEGHALAYA              614
# MIZORAM                562
# NAGALAND               330
# D & N HAVELI           326
# PUDUCHERRY             210
# A & N ISLANDS          144
# DAMAN & DIU            134
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = CRB.index[:10], y = CRB[:10]).set(title = "Criminal Breach of trust by Each state")
# Out:
# [Text(0.5, 1.0, 'Criminal Breach of trust by Each state')]

# %%
Cheat = df1.groupby("STATE/UT")["CHEATING"].sum().sort_values(ascending=False)

print("Cheating")
Cheat
# Out:
# Cheating
# STATE/UT
# RAJASTHAN            281600
# ANDHRA PRADESH       197686
# UTTAR PRADESH        167920
# MAHARASHTRA          159804
# KARNATAKA             92670
# KERALA                87516
# PUNJAB                75872
# TAMIL NADU            63378
# WEST BENGAL           61662
# BIHAR                 61380
# DELHI UT              52256
# MADHYA PRADESH        36990
# GUJARAT               34132
# HARYANA               31150
# ODISHA                26740
# ASSAM                 24782
# JHARKHAND             18952
# CHHATTISGARH          13996
# UTTARAKHAND           11220
# JAMMU & KASHMIR       10926
# HIMACHAL PRADESH       5306
# CHANDIGARH             4602
# MANIPUR                2462
# GOA                    2352
# MEGHALAYA              2030
# TRIPURA                1704
# MIZORAM                1486
# PUDUCHERRY             1128
# ARUNACHAL PRADESH      1040
# NAGALAND                758
# SIKKIM                  700
# A & N ISLANDS           506
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Cheat.index[:10], y = Cheat[:10]).set(title = "Cheating by Each state")
# Out:
# [Text(0.5, 1.0, 'Cheating by Each state')]

# %%
Counter = df1.groupby("STATE/UT")["COUNTERFIETING"].sum().sort_values(ascending=False)

print("Counterfieting")
Counter
# Out:
# Counterfieting
# STATE/UT
# MAHARASHTRA          7612
# UTTAR PRADESH        6448
# ANDHRA PRADESH       6214
# GUJARAT              5164
# TAMIL NADU           4840
# WEST BENGAL          3842
# KARNATAKA            3126
# KERALA               2186
# ASSAM                1796
# BIHAR                1652
# PUNJAB               1486
# RAJASTHAN            1452
# CHHATTISGARH         1156
# DELHI UT             1040
# MADHYA PRADESH        848
# HARYANA               744
# JAMMU & KASHMIR       636
# UTTARAKHAND           526
# ODISHA                484
# JHARKHAND             406
# GOA                   324
# TRIPURA               266
# MIZORAM               242
# MANIPUR               182
# MEGHALAYA             176
# NAGALAND              108
# HIMACHAL PRADESH      108
# ARUNACHAL PRADESH     104
# PUDUCHERRY             64
# DAMAN & DIU            60
# CHANDIGARH             54
# SIKKIM                 38
# D & N HAVELI           28
# A & N ISLANDS          22
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Counter.index[:10], y = Counter[:10]).set(title = "Counterfieting by Each state")
# Out:
# [Text(0.5, 1.0, 'Counterfieting by Each state')]

# %%
ARSON = df1.groupby("STATE/UT")["ARSON"].sum().sort_values(ascending=False)

print("Arson")
ARSON
# Out:
# Arson
# STATE/UT
# MAHARASHTRA          29030
# ANDHRA PRADESH       23936
# MADHYA PRADESH       20708
# BIHAR                17018
# RAJASTHAN            16624
# TAMIL NADU           16298
# ASSAM                15836
# GUJARAT              11294
# KERALA               11160
# ODISHA               10560
# UTTAR PRADESH         9108
# KARNATAKA             7422
# JAMMU & KASHMIR       6332
# CHHATTISGARH          6294
# WEST BENGAL           4728
# JHARKHAND             4024
# HARYANA               3812
# HIMACHAL PRADESH      2968
# MANIPUR               1904
# PUNJAB                1814
# DELHI UT              1128
# TRIPURA               1096
# MEGHALAYA              886
# UTTARAKHAND            628
# GOA                    544
# MIZORAM                534
# ARUNACHAL PRADESH      500
# PUDUCHERRY             380
# A & N ISLANDS          196
# SIKKIM                 160
# NAGALAND               140
# CHANDIGARH             124
# D & N HAVELI           110
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = ARSON.index[:10], y = ARSON[:10]).set(title = "Arson by Each state")
# Out:
# [Text(0.5, 1.0, 'Arson by Each state')]

# %%
Hurt = df1.groupby("STATE/UT")["HURT/GREVIOUS HURT"].sum().sort_values(ascending=False)

print("Hurt")
Hurt
# Out:
# Hurt
# STATE/UT
# ANDHRA PRADESH       1093130
# MADHYA PRADESH        825154
# MAHARASHTRA           707520
# TAMIL NADU            561346
# RAJASTHAN             534706
# KARNATAKA             502664
# KERALA                464902
# BIHAR                 378532
# UTTAR PRADESH         279500
# GUJARAT               270436
# WEST BENGAL           188304
# CHHATTISGARH          170052
# ODISHA                151522
# ASSAM                 138366
# PUNJAB                113840
# HARYANA               102508
# JHARKHAND              80474
# DELHI UT               44420
# HIMACHAL PRADESH       31818
# PUDUCHERRY             21388
# UTTARAKHAND            21220
# TRIPURA                18612
# ARUNACHAL PRADESH      10314
# JAMMU & KASHMIR         7766
# MANIPUR                 6866
# GOA                     4574
# MEGHALAYA               3472
# MIZORAM                 2432
# A & N ISLANDS           2210
# SIKKIM                  1878
# CHANDIGARH              1632
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Hurt.index[:10], y = Hurt[:10]).set(title = "HUrt/Grevious Hurt by Each state")
# Out:
# [Text(0.5, 1.0, 'HUrt/Grevious Hurt by Each state')]

# %%
DD = df1.groupby("STATE/UT")["DOWRY DEATHS"].sum().sort_values(ascending=False)

print("Dowry Deaths")
DD
# Out:
# Dowry Deaths
# STATE/UT
# UTTAR PRADESH        47648
# BIHAR                27096
# MADHYA PRADESH       18072
# ANDHRA PRADESH       12430
# WEST BENGAL          10344
# RAJASTHAN            10132
# ODISHA                9110
# MAHARASHTRA           8498
# JHARKHAND             6582
# HARYANA               6260
# KARNATAKA             5836
# TAMIL NADU            4634
# DELHI UT              3164
# PUNJAB                3092
# ASSAM                 2552
# CHHATTISGARH          2284
# UTTARAKHAND           1812
# GUJARAT               1004
# TRIPURA                628
# KERALA                 602
# JAMMU & KASHMIR        270
# HIMACHAL PRADESH       110
# CHANDIGARH              84
# PUDUCHERRY              52
# GOA                     38
# MEGHALAYA               30
# A & N ISLANDS           12
# MIZORAM                  8
# DAMAN & DIU              6
# MANIPUR                  4
# SIKKIM                   4
# ARUNACHAL PRADESH        4
# D & N HAVELI             2
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = DD.index[:10], y = DD[:10]).set(title = "Dowry Deaths by Each state")
# Out:
# [Text(0.5, 1.0, 'Dowry Deaths by Each state')]

# %%
Assault = df1.groupby("STATE/UT")["ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY"].sum().sort_values(ascending=False)

print("ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY")
Assault
# Out:
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY
# STATE/UT
# MADHYA PRADESH       159756
# ANDHRA PRADESH       103998
# MAHARASHTRA           78438
# KERALA                62980
# RAJASTHAN             61706
# ODISHA                59892
# UTTAR PRADESH         59396
# KARNATAKA             47398
# WEST BENGAL           45742
# TAMIL NADU            38658
# CHHATTISGARH          38330
# ASSAM                 27240
# JAMMU & KASHMIR       23018
# GUJARAT               17996
# BIHAR                 15152
# DELHI UT              15068
# HARYANA               10646
# PUNJAB                 8094
# JHARKHAND              7970
# HIMACHAL PRADESH       7194
# TRIPURA                5546
# UTTARAKHAND            3090
# MIZORAM                1632
# ARUNACHAL PRADESH      1568
# PUDUCHERRY             1226
# MEGHALAYA              1064
# MANIPUR                1008
# GOA                     656
# CHANDIGARH              628
# SIKKIM                  460
# A & N ISLANDS           428
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Assault.index[:10], y = Assault[:10]).set(title = "Assault on women with intent to outrage her modesty by Each state")
# Out:
# [Text(0.5, 1.0, 'Assault on women with intent to outrage her modesty by Each state')]

# %%
Insult = df1.groupby("STATE/UT")["INSULT TO MODESTY OF WOMEN"].sum().sort_values(ascending=False)

print("INSULT TO MODESTY OF WOMEN")
Insult
# Out:
# INSULT TO MODESTY OF WOMEN
# STATE/UT
# ANDHRA PRADESH       72262
# UTTAR PRADESH        53022
# MAHARASHTRA          24220
# TAMIL NADU           20086
# MADHYA PRADESH       18634
# HARYANA              16376
# JAMMU & KASHMIR       7986
# KERALA                6608
# ODISHA                5878
# CHHATTISGARH          3450
# DELHI UT              3374
# WEST BENGAL           3108
# UTTARAKHAND           3038
# GUJARAT               2730
# KARNATAKA             1662
# PUNJAB                1524
# HIMACHAL PRADESH       878
# RAJASTHAN              708
# PUDUCHERRY             568
# JHARKHAND              494
# BIHAR                  452
# CHANDIGARH             286
# GOA                    246
# ASSAM                  224
# A & N ISLANDS           86
# TRIPURA                 78
# ARUNACHAL PRADESH       36
# SIKKIM                  28
# NAGALAND                20
# MEGHALAYA               16
# MIZORAM                 12
# D & N HAVELI             8
# MANIPUR                  6
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Insult.index[:10], y = Insult[:10]).set(title = "Insult to modesty of women by Each state")
# Out:
# [Text(0.5, 1.0, 'Insult to modesty of women by Each state')]

# %%
Cruelty = df1.groupby("STATE/UT")["CRUELTY BY HUSBAND OR HIS RELATIVES"].sum().sort_values(ascending=False)

print("CRUELTY BY HUSBAND OR HIS RELATIVES")
Cruelty
# Out:
# CRUELTY BY HUSBAND OR HIS RELATIVES
# STATE/UT
# WEST BENGAL          261336
# ANDHRA PRADESH       238014
# RAJASTHAN            200202
# MAHARASHTRA          160726
# UTTAR PRADESH        155234
# GUJARAT              118862
# KERALA                92148
# MADHYA PRADESH        79938
# ASSAM                 78776
# KARNATAKA             60104
# HARYANA               54224
# BIHAR                 51360
# ODISHA                37394
# TAMIL NADU            36376
# DELHI UT              30422
# PUNJAB                23996
# CHHATTISGARH          19146
# JHARKHAND             16818
# TRIPURA               13028
# UTTARAKHAND            8284
# HIMACHAL PRADESH       6490
# JAMMU & KASHMIR        3600
# CHANDIGARH             1614
# MANIPUR                 438
# GOA                     382
# ARUNACHAL PRADESH       334
# MEGHALAYA               330
# A & N ISLANDS           242
# PUDUCHERRY              210
# MIZORAM                 108
# SIKKIM                   88
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Cruelty.index[:10], y = Cruelty[:10]).set(title = "CRUELTY BY HUSBAND OR HIS RELATIVES by Each state")
# Out:
# [Text(0.5, 1.0, 'CRUELTY BY HUSBAND OR HIS RELATIVES by Each state')]

# %%
Importation = df1.groupby("STATE/UT")["IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES"].sum().sort_values(ascending=False)

print("IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES")
Importation
# Out:
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES
# STATE/UT
# BIHAR                880
# JHARKHAND            290
# WEST BENGAL          228
# MADHYA PRADESH       120
# KARNATAKA             94
# ODISHA                36
# ANDHRA PRADESH        34
# TAMIL NADU            30
# ASSAM                 16
# RAJASTHAN             12
# CHHATTISGARH          10
# MEGHALAYA              8
# UTTAR PRADESH          6
# MIZORAM                6
# PUNJAB                 4
# MAHARASHTRA            4
# DELHI UT               2
# NAGALAND               2
# UTTARAKHAND            2
# SIKKIM                 0
# PUDUCHERRY             0
# TRIPURA                0
# A & N ISLANDS          0
# MANIPUR                0
# LAKSHADWEEP            0
# JAMMU & KASHMIR        0
# HIMACHAL PRADESH       0
# HARYANA                0
# GUJARAT                0
# GOA                    0
# DAMAN & DIU            0
# D & N HAVELI           0
# CHANDIGARH             0
# ARUNACHAL PRADESH      0
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Importation.index[:10], y = Importation[:10]).set(title = "IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES by Each state")
# Out:
# [Text(0.5, 1.0, 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES by Each state')]

# %%
Negligence = df1.groupby("STATE/UT")["CAUSING DEATH BY NEGLIGENCE"].sum().sort_values(ascending=False)

print("CAUSING DEATH BY NEGLIGENCE")
Negligence
# Out:
# CAUSING DEATH BY NEGLIGENCE
# STATE/UT
# TAMIL NADU           280386
# ANDHRA PRADESH       276870
# MAHARASHTRA          269226
# UTTAR PRADESH        227642
# RAJASTHAN            156700
# MADHYA PRADESH       129938
# GUJARAT              108770
# BIHAR                 88884
# WEST BENGAL           75502
# ODISHA                73014
# PUNJAB                66678
# ASSAM                 60410
# CHHATTISGARH          50864
# HARYANA               30394
# JHARKHAND             27224
# DELHI UT              15006
# UTTARAKHAND           13360
# HIMACHAL PRADESH      12618
# KARNATAKA             10156
# JAMMU & KASHMIR        9048
# GOA                    5328
# PUDUCHERRY             5204
# TRIPURA                3084
# ARUNACHAL PRADESH      1490
# MEGHALAYA              1364
# KERALA                  978
# SIKKIM                  844
# NAGALAND                744
# MIZORAM                 630
# DAMAN & DIU             622
# D & N HAVELI            296
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = Negligence.index[:10], y = Negligence[:10]).set(title = "CAUSING DEATH BY NEGLIGENCE by Each state")
# Out:
# [Text(0.5, 1.0, 'CAUSING DEATH BY NEGLIGENCE by Each state')]

# %%
OIC = df1.groupby("STATE/UT")["OTHER IPC CRIMES"].sum().sort_values(ascending=False)

print("OTHER IPC CRIMES")
OIC
# Out:
# OTHER IPC CRIMES
# STATE/UT
# MADHYA PRADESH       2393164
# TAMIL NADU           2372230
# KERALA               1659766
# RAJASTHAN            1569982
# GUJARAT              1459368
# KARNATAKA            1362672
# UTTAR PRADESH        1253898
# MAHARASHTRA          1120120
# BIHAR                1077182
# ANDHRA PRADESH        964504
# WEST BENGAL           852388
# ODISHA                492412
# CHHATTISGARH          491710
# DELHI UT              474914
# HARYANA               449688
# ASSAM                 362708
# JHARKHAND             308478
# JAMMU & KASHMIR       265842
# PUNJAB                232054
# HIMACHAL PRADESH      174356
# PUDUCHERRY             54980
# UTTARAKHAND            52676
# TRIPURA                28088
# MANIPUR                25474
# CHANDIGARH             23210
# GOA                    19896
# ARUNACHAL PRADESH      14792
# MEGHALAYA              12528
# MIZORAM                11824
# A & N ISLANDS           8886
# NAGALAND                6100
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x = OIC.index[:10], y = OIC[:10]).set(title = "Other IPC Crimes by Each state")
# Out:
# [Text(0.5, 1.0, 'Other IPC Crimes by Each state')]

# %%
df4
# Out:
#                    TOTAL IPC CRIMES Literacy Rate
# STATE/UT
# A & N ISLANDS                 18204        86.63%
# ANDHRA PRADESH              4037962        67.02%
# ARUNACHAL PRADESH             55304        65.38%
# ASSAM                       1195528        72.19%
# BIHAR                       2692586        61.80%
# CHANDIGARH                    81614        86.05%
# CHHATTISGARH                1122054        70.28%
# D & N HAVELI                   9302        76.24%
# DAMAN & DIU                    5896        87.10%
# DELHI UT                    1266348        86.21%
# GOA                           64102        88.70%
# GUJARAT                     2771550        78.03%
# HARYANA                     1190606        75.55%
# HIMACHAL PRADESH             309896        82.80%
# JAMMU & KASHMIR              518310        67.16%
# JHARKHAND                    844702        66.41%
# KARNATAKA                   2962126        75.36%
# KERALA                      2874918        94.00%
# ...

# %%
df4.insert(2, "Area of State/Ut(in Sq.km.)", [8249,
275045,
83743,
78438,
94163,
114,
135192,
491,
111,
1483,
3702,
196244,
44212,
55673,
222236,
79716,
191791,
38852,
30,
308252,
307713,
22327,
22429,
21081,
16579,
155707,
490,
50362,
342239,
7096,
130060,
10486,
240928,
53483,
88752
])

# %%
df4
# Out:
#                    TOTAL IPC CRIMES Literacy Rate  Area of State/Ut(in Sq.km.)
# STATE/UT
# A & N ISLANDS                 18204        86.63%                         8249
# ANDHRA PRADESH              4037962        67.02%                       275045
# ARUNACHAL PRADESH             55304        65.38%                        83743
# ASSAM                       1195528        72.19%                        78438
# BIHAR                       2692586        61.80%                        94163
# CHANDIGARH                    81614        86.05%                          114
# CHHATTISGARH                1122054        70.28%                       135192
# D & N HAVELI                   9302        76.24%                          491
# DAMAN & DIU                    5896        87.10%                          111
# DELHI UT                    1266348        86.21%                         1483
# GOA                           64102        88.70%                         3702
# ...

# %%
df4['STATE/UT']= df4.index

# %%
df4
# Out:
#                    TOTAL IPC CRIMES Literacy Rate  \
# STATE/UT
# A & N ISLANDS                 18204        86.63%
# ANDHRA PRADESH              4037962        67.02%
# ARUNACHAL PRADESH             55304        65.38%
# ASSAM                       1195528        72.19%
# BIHAR                       2692586        61.80%
# CHANDIGARH                    81614        86.05%
# CHHATTISGARH                1122054        70.28%
# D & N HAVELI                   9302        76.24%
# DAMAN & DIU                    5896        87.10%
# DELHI UT                    1266348        86.21%
# GOA                           64102        88.70%
# GUJARAT                     2771550        78.03%
# HARYANA                     1190606        75.55%
# HIMACHAL PRADESH             309896        82.80%
# JAMMU & KASHMIR              518310        67.16%
# JHARKHAND                    844702        66.41%
# KARNATAKA                   2962126        75.36%
# ...

# %%
df4.plot(x="STATE/UT", y=["Area of State/Ut(in Sq.km.)", "TOTAL IPC CRIMES"], kind="bar")
# Out:
# <AxesSubplot:xlabel='STATE/UT'>

# %%
plt.figure(figsize=(30,20))
df4.plot(x="STATE/UT", y=["Area of State/Ut(in Sq.km.)", "TOTAL IPC CRIMES"], kind="line")
# Out:
# <AxesSubplot:xlabel='STATE/UT'>

# %%
##FRom the Bar as well as line graph we can see a positive relation between area of the state and Total crimes of each state.

# %%
df4.insert(2, "Population of each state(2011)", [379944,
49386799,
1382611,
31169272,
103804630,
1054686,
25540196,
342853,
242911,
16753235,
1457723,
60383628,
25753081,
6856509,
12548926,
32988134,
61130704,
33387677,
64429,
72597565,
112372972,
2721756,
2964007,
1091014,
1980602,
41947358,
1244464,
27704236,
68621012,
607688,
72138958,
3671032,
199581477,
10116752,
91347736
])

# %%
df4
# Out:
#                    TOTAL IPC CRIMES Literacy Rate  \
# STATE/UT
# A & N ISLANDS                 18204        86.63%
# ANDHRA PRADESH              4037962        67.02%
# ARUNACHAL PRADESH             55304        65.38%
# ASSAM                       1195528        72.19%
# BIHAR                       2692586        61.80%
# CHANDIGARH                    81614        86.05%
# CHHATTISGARH                1122054        70.28%
# D & N HAVELI                   9302        76.24%
# DAMAN & DIU                    5896        87.10%
# DELHI UT                    1266348        86.21%
# GOA                           64102        88.70%
# GUJARAT                     2771550        78.03%
# HARYANA                     1190606        75.55%
# HIMACHAL PRADESH             309896        82.80%
# JAMMU & KASHMIR              518310        67.16%
# JHARKHAND                    844702        66.41%
# KARNATAKA                   2962126        75.36%
# ...

# %%
df4.plot(x="STATE/UT", y=["Population of each state(2011)", "TOTAL IPC CRIMES"], kind="bar")
# Out:
# <AxesSubplot:xlabel='STATE/UT'>

# %%
df4.sort_values(by="Population of each state(2011)", ascending=False, inplace=True)
df4
# Out:
#                    TOTAL IPC CRIMES Literacy Rate  \
# STATE/UT
# UTTAR PRADESH               3716148        67.68%
# MAHARASHTRA                 4546872        82.34%
# BIHAR                       2692586        61.80%
# WEST BENGAL                 2238608        76.26%
# MADHYA PRADESH              4827540        69.32%
# TAMIL NADU                  4120352        80.33%
# RAJASTHAN                   3711832        66.11%
# KARNATAKA                   2962126        75.36%
# GUJARAT                     2771550        78.03%
# ANDHRA PRADESH              4037962        67.02%
# ODISHA                      1295892        72.87%
# KERALA                      2874918        94.00%
# JHARKHAND                    844702        66.41%
# ASSAM                       1195528        72.19%
# PUNJAB                       768262        75.84%
# HARYANA                     1190606        75.55%
# CHHATTISGARH                1122054        70.28%
# ...

# %%
##From the above analysis we can see that as the population is decreasing the number of total crimes is also decreasing, but
it is only true for some of the state/ut. In some states even though the population is lesser than the above state, the no.
of crimes is still higher than the above state.

# %%
##From the above analysis of crimes by each state on differnt crimes, it is seen that Uttar Pradesh, Maharashtra and Bihar 
has the max no. of crimes. These states are almost present in Top 10 States of every crime. 
Taking Maharashtra into account, its area is smaller than UP but has a higher literacy rate than UP and so the no. of TOTAL
IPC CRIMES. 
Meanwhile if we look at Madhya Pradesh which has the highest no. of TOTAL IPC CRIMES, we can see that its area is also higher
than that of both Uttar pradesh and Maharashtra, and also has a literacy rate higher than UP but still has more no. of crimes.

More than LIteracy Rate, we can see a  somewhat a relation with Area of the state to the no. of Crimes.

##Madhya pradesh has highest no. of Total ipc crimes followed by MAharashtra and Tamil nadu. Whereas, Lashadweep has least 
no.of total ipc crimes followed by D&Diu Islands and D&N Haveli.
